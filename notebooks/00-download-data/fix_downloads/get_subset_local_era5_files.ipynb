# %%
import os
import pandas as pd
from pathlib import Path
import xarray as xr

# %% [markdown]
# # Get relevant variables from local ERA5 netcdf files
# This notebook obtains a subset of locally downloaded ERA5 files containing only the variables relevant to the downscaling model

# %% [markdown]
# ### Input parameters

# %%
RAW_DIR = Path("/mnt/c/Users/JCPeralta/Downloads/ERA5_converted")
DEST_DIR = Path("../../data/01-raw/era5")

# %%
VARIABLES = ["u10", "v10", "d2m", "t2m", "sp", "tp", "tcc"]

# %% [markdown]
# ### Get subset containing specified variables and save

# %%
for fn in [fn for fn in os.listdir(RAW_DIR) if "idx" not in fn]:
    print(fn)
    output_filename = f"ERA5_PH_{fn.split('_')[2]}.nc"
    ds = xr.open_dataset(RAW_DIR / fn)
    ds = ds[VARIABLES]
    ds.to_netcdf(DEST_DIR / output_filename)
# Out:
# ERA5_PH_200301_surface_hourly.nc
# ERA5_PH_200302_surface_hourly.nc
# ERA5_PH_200303_surface_hourly.nc
# ERA5_PH_200304_surface_hourly.nc
# ERA5_PH_200305_surface_hourly.nc
# ERA5_PH_200306_surface_hourly.nc
# ERA5_PH_200307_surface_hourly.nc
# ERA5_PH_200308_surface_hourly.nc
# ERA5_PH_200309_surface_hourly.nc
# ERA5_PH_200310_surface_hourly.nc
# ERA5_PH_200311_surface_hourly.nc
# ERA5_PH_200312_surface_hourly.nc
# ERA5_PH_200401_surface_hourly.nc
# ERA5_PH_200402_surface_hourly.nc
# ERA5_PH_200403_surface_hourly.nc
# ERA5_PH_200404_surface_hourly.nc
# ERA5_PH_200405_surface_hourly.nc
# ERA5_PH_200406_surface_hourly.nc
# ERA5_PH_200407_surface_hourly.nc
# ERA5_PH_200408_surface_hourly.nc
# ERA5_PH_200409_surface_hourly.nc
# ERA5_PH_200410_surface_hourly.nc
# ERA5_PH_200411_surface_hourly.nc
# ERA5_PH_200412_surface_hourly.nc
# ERA5_PH_200501_surface_hourly.nc
# ERA5_PH_200502_surface_hourly.nc
# ERA5_PH_200503_surface_hourly.nc
# ERA5_PH_200504_surface_hourly.nc
# ERA5_PH_200505_surface_hourly.nc
# ERA5_PH_200506_surface_hourly.nc
# ERA5_PH_200507_surface_hourly.nc
# ERA5_PH_200508_surface_hourly.nc
# ERA5_PH_200509_surface_hourly.nc
# ERA5_PH_200510_surface_hourly.nc
# ERA5_PH_200511_surface_hourly.nc
# ERA5_PH_200512_surface_hourly.nc
# ERA5_PH_200601_surface_hourly.nc
# ERA5_PH_200602_surface_hourly.nc
# ERA5_PH_200603_surface_hourly.nc
# ERA5_PH_200604_surface_hourly.nc
# ERA5_PH_200605_surface_hourly.nc
# ERA5_PH_200606_surface_hourly.nc
# ERA5_PH_200607_surface_hourly.nc
# ERA5_PH_200608_surface_hourly.nc
# ERA5_PH_200609_surface_hourly.nc
# ERA5_PH_200610_surface_hourly.nc
# ERA5_PH_200611_surface_hourly.nc
# ERA5_PH_200612_surface_hourly.nc
# ERA5_PH_200701_surface_hourly.nc
# ERA5_PH_200702_surface_hourly.nc
# ERA5_PH_200703_surface_hourly.nc
# ERA5_PH_200704_surface_hourly.nc
# ERA5_PH_200705_surface_hourly.nc
# ERA5_PH_200706_surface_hourly.nc
# ERA5_PH_200707_surface_hourly.nc
# ERA5_PH_200708_surface_hourly.nc
# ERA5_PH_200709_surface_hourly.nc
# ERA5_PH_200710_surface_hourly.nc
# ERA5_PH_200711_surface_hourly.nc
# ERA5_PH_200712_surface_hourly.nc
# ERA5_PH_200801_surface_hourly.nc
# ERA5_PH_200802_surface_hourly.nc
# ERA5_PH_200803_surface_hourly.nc
# ERA5_PH_200804_surface_hourly.nc
# ERA5_PH_200805_surface_hourly.nc
# ERA5_PH_200806_surface_hourly.nc
# ERA5_PH_200807_surface_hourly.nc
# ERA5_PH_200808_surface_hourly.nc
# ERA5_PH_200809_surface_hourly.nc
# ERA5_PH_200810_surface_hourly.nc
# ERA5_PH_200811_surface_hourly.nc
# ERA5_PH_200812_surface_hourly.nc
# ERA5_PH_200901_surface_hourly.nc
# ERA5_PH_200902_surface_hourly.nc
# ERA5_PH_200903_surface_hourly.nc
# ERA5_PH_200904_surface_hourly.nc
# ERA5_PH_200905_surface_hourly.nc
# ERA5_PH_200906_surface_hourly.nc
# ERA5_PH_200907_surface_hourly.nc
# ERA5_PH_200908_surface_hourly.nc
# ERA5_PH_200909_surface_hourly.nc
# ERA5_PH_200910_surface_hourly.nc
# ERA5_PH_200911_surface_hourly.nc
# ERA5_PH_200912_surface_hourly.nc
# ERA5_PH_201001_surface_hourly.nc
# ERA5_PH_201002_surface_hourly.nc
# ERA5_PH_201003_surface_hourly.nc
# ERA5_PH_201004_surface_hourly.nc
# ERA5_PH_201005_surface_hourly.nc
# ERA5_PH_201006_surface_hourly.nc
# ERA5_PH_201007_surface_hourly.nc
# ERA5_PH_201008_surface_hourly.nc
# ERA5_PH_201009_surface_hourly.nc
# ERA5_PH_201010_surface_hourly.nc
# ERA5_PH_201011_surface_hourly.nc
# ERA5_PH_201012_surface_hourly.nc
# ERA5_PH_201101_surface_hourly.nc
# ERA5_PH_201102_surface_hourly.nc
# ERA5_PH_201103_surface_hourly.nc
# ERA5_PH_201104_surface_hourly.nc
# ERA5_PH_201105_surface_hourly.nc
# ERA5_PH_201106_surface_hourly.nc
# ERA5_PH_201107_surface_hourly.nc
# ERA5_PH_201108_surface_hourly.nc
# ERA5_PH_201109_surface_hourly.nc
# ERA5_PH_201110_surface_hourly.nc
# ERA5_PH_201111_surface_hourly.nc
# ERA5_PH_201112_surface_hourly.nc
# ERA5_PH_201201_surface_hourly.nc
# ERA5_PH_201202_surface_hourly.nc
# ERA5_PH_201203_surface_hourly.nc
# ERA5_PH_201204_surface_hourly.nc
# ERA5_PH_201205_surface_hourly.nc
# ERA5_PH_201206_surface_hourly.nc
# ERA5_PH_201207_surface_hourly.nc
# ERA5_PH_201208_surface_hourly.nc
# ERA5_PH_201209_surface_hourly.nc
# ERA5_PH_201210_surface_hourly.nc
# ERA5_PH_201211_surface_hourly.nc
# ERA5_PH_201212_surface_hourly.nc
# ERA5_PH_201301_surface_hourly.nc
# ERA5_PH_201302_surface_hourly.nc
# ERA5_PH_201303_surface_hourly.nc
# ERA5_PH_201304_surface_hourly.nc
# ERA5_PH_201305_surface_hourly.nc
# ERA5_PH_201306_surface_hourly.nc
# ERA5_PH_201307_surface_hourly.nc
# ERA5_PH_201308_surface_hourly.nc
# ERA5_PH_201309_surface_hourly.nc
# ERA5_PH_201310_surface_hourly.nc
# ERA5_PH_201311_surface_hourly.nc
# ERA5_PH_201312_surface_hourly.nc
# ERA5_PH_201401_surface_hourly.nc
# ERA5_PH_201402_surface_hourly.nc
# ERA5_PH_201403_surface_hourly.nc
# ERA5_PH_201404_surface_hourly.nc
# ERA5_PH_201405_surface_hourly.nc
# ERA5_PH_201406_surface_hourly.nc
# ERA5_PH_201407_surface_hourly.nc
# ERA5_PH_201408_surface_hourly.nc
# ERA5_PH_201409_surface_hourly.nc
# ERA5_PH_201410_surface_hourly.nc
# ERA5_PH_201411_surface_hourly.nc
# ERA5_PH_201412_surface_hourly.nc
# ERA5_PH_201501_surface_hourly.nc
# ERA5_PH_201502_surface_hourly.nc
# ERA5_PH_201503_surface_hourly.nc
# ERA5_PH_201504_surface_hourly.nc
# ERA5_PH_201505_surface_hourly.nc
# ERA5_PH_201506_surface_hourly.nc
# ERA5_PH_201507_surface_hourly.nc
# ERA5_PH_201508_surface_hourly.nc
# ERA5_PH_201509_surface_hourly.nc
# ERA5_PH_201510_surface_hourly.nc
# ERA5_PH_201511_surface_hourly.nc
# ERA5_PH_201512_surface_hourly.nc
# ERA5_PH_201601_surface_hourly.nc
# ERA5_PH_201602_surface_hourly.nc
# ERA5_PH_201603_surface_hourly.nc
# ERA5_PH_201604_surface_hourly.nc
# ERA5_PH_201605_surface_hourly.nc
# ERA5_PH_201606_surface_hourly.nc
# ERA5_PH_201607_surface_hourly.nc
# ERA5_PH_201608_surface_hourly.nc
# ERA5_PH_201609_surface_hourly.nc
# ERA5_PH_201610_surface_hourly.nc
# ERA5_PH_201611_surface_hourly.nc
# ERA5_PH_201612_surface_hourly.nc
# ERA5_PH_201701_surface_hourly.nc
# ERA5_PH_201702_surface_hourly.nc
# ERA5_PH_201703_surface_hourly.nc
# ERA5_PH_201704_surface_hourly.nc
# ERA5_PH_201705_surface_hourly.nc
# ERA5_PH_201706_surface_hourly.nc
# ERA5_PH_201707_surface_hourly.nc
# ERA5_PH_201708_surface_hourly.nc
# ERA5_PH_201709_surface_hourly.nc
# ERA5_PH_201710_surface_hourly.nc
# ERA5_PH_201711_surface_hourly.nc
# ERA5_PH_201712_surface_hourly.nc
# ERA5_PH_201801_surface_hourly.nc
# ERA5_PH_201802_surface_hourly.nc
# ERA5_PH_201803_surface_hourly.nc
# ERA5_PH_201804_surface_hourly.nc
# ERA5_PH_201805_surface_hourly.nc
# ERA5_PH_201806_surface_hourly.nc
# ERA5_PH_201807_surface_hourly.nc
# ERA5_PH_201808_surface_hourly.nc
# ERA5_PH_201809_surface_hourly.nc
# ERA5_PH_201810_surface_hourly.nc
# ERA5_PH_201811_surface_hourly.nc
# ERA5_PH_201812_surface_hourly.nc
# ERA5_PH_201901_surface_hourly.nc
# ERA5_PH_201902_surface_hourly.nc
# ERA5_PH_201903_surface_hourly.nc
# ERA5_PH_201904_surface_hourly.nc
# ERA5_PH_201905_surface_hourly.nc
# ERA5_PH_201906_surface_hourly.nc
# ERA5_PH_201907_surface_hourly.nc
# ERA5_PH_201908_surface_hourly.nc
# ERA5_PH_201909_surface_hourly.nc
# ERA5_PH_201910_surface_hourly.nc
# ERA5_PH_201911_surface_hourly.nc
# ERA5_PH_201912_surface_hourly.nc
# ERA5_PH_202001_surface_hourly.nc
# ERA5_PH_202002_surface_hourly.nc
# ERA5_PH_202003_surface_hourly.nc
# ERA5_PH_202004_surface_hourly.nc
# ERA5_PH_202005_surface_hourly.nc
# ERA5_PH_202006_surface_hourly.nc
# ERA5_PH_202007_surface_hourly.nc
# ERA5_PH_202008_surface_hourly.nc
# ERA5_PH_202009_surface_hourly.nc
# ERA5_PH_202010_surface_hourly.nc
# ERA5_PH_202011_surface_hourly.nc
# ERA5_PH_202012_surface_hourly.nc
# ERA5_PH_202101_surface_hourly.nc
# ERA5_PH_202102_surface_hourly.nc
# ERA5_PH_202103_surface_hourly.nc
# ERA5_PH_202104_surface_hourly.nc
# ERA5_PH_202105_surface_hourly.nc
# ERA5_PH_202106_surface_hourly.nc
# ERA5_PH_202107_surface_hourly.nc
# ERA5_PH_202108_surface_hourly.nc
# ERA5_PH_202109_surface_hourly.nc
# ERA5_PH_202110_surface_hourly.nc
# ERA5_PH_202111_surface_hourly.nc
# ERA5_PH_202112_surface_hourly.nc
# ERA5_PH_202201_surface_hourly.nc
# ERA5_PH_202202_surface_hourly.nc
# ERA5_PH_202203_surface_hourly.nc
# ERA5_PH_202204_surface_hourly.nc
# ERA5_PH_202205_surface_hourly.nc
# ERA5_PH_202206_surface_hourly.nc
# ERA5_PH_202207_surface_hourly.nc
# ERA5_PH_202208_surface_hourly.nc
# ERA5_PH_202209_surface_hourly.nc
# ERA5_PH_202210_surface_hourly.nc
# ERA5_PH_202211_surface_hourly.nc
# ERA5_PH_202212_surface_hourly.nc

# %% [markdown]
# ### Check if all files are complete

# %%
fns = [fn.split("_")[2] for fn in os.listdir(DEST_DIR)]
complete_dates = pd.date_range(
    start="2003-01-01", end="2022-12-01", freq="MS"
).strftime("%Y%m")
[fn for fn in complete_dates if fn not in fns]
# Out:
# []
