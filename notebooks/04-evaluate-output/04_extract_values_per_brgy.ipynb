# %% [markdown]
# # Extract Downscaled Variables from Gridded Data to Table
# The goal is to generate a table with each barangay represented by a row, containing the average of all grids covered by the corresponding barangay shapefile.

# %%
import os, sys
from pathlib import Path
import time

import numpy as np
import pandas as pd
import geopandas as gpd
from shapely.geometry import Polygon
import xarray as xr
import rioxarray as rxr

from functools import partial
import matplotlib.pyplot as plt
import glob

import sys
import ast
sys.path.append("../../")

# %% [markdown]
# ## Define paths

# %%
RAW_INPUT_PATH = Path("../../data/01-raw/")
RESULTS_PATH = Path("../../data/03-results/")
FIGS_PATH = Path("../../figs/")
YEARS = np.arange(2003,2023,1)
VARIABLE = 'tave'

os.makedirs(RESULTS_PATH / 'table_extracts', exist_ok=True)

# %% [markdown]
# ## Define excluded years based on metrics
# List down outputs that have metrics below the criteria threshold. These will be excluded from the tables

# %%
if VARIABLE == 'precip': 
    EXCLUDED_CITIES = ['Legazpi']
elif VARIABLE == 'tmin': 
    EXCLUDED_CITIES = ['Davao','CagayanDeOro','Legazpi', 'Muntinlupa','Navotas','Mandaluyong']
elif VARIABLE == 'tmax': 
    EXCLUDED_CITIES = ['Legazpi', 'Mandaue']
elif VARIABLE == 'tave': 
    EXCLUDED_CITIES = ['Davao','CagayanDeOro','Legazpi', 'Muntinlupa','Navotas','Mandaluyong','Legazpi', 'Mandaue']

# %% [markdown]
# ## Read bounds

# %%
bounds_df = pd.read_csv(RAW_INPUT_PATH / 'domains' / 'downscaling_domains_fixed.csv')
bounds_df['full_bounds'] = bounds_df['full_bounds'].apply(ast.literal_eval)
bounds_df['focused_bounds'] = bounds_df['focused_bounds'].apply(ast.literal_eval)
bounds_df
# Out:
#            city                                        full_bounds  \
# 0       Dagupan  [120.00931049408791, 120.4821769636825, 15.907...
# 1       Palayan  [120.8625098711998, 121.33347866342953, 15.294...
# 2   MetroManila  [120.8470354518582, 121.22452516891933, 14.273...
# 3       Legazpi  [123.63316781038878, 123.90749473184147, 12.97...
# 4        Iloilo  [122.41374050886832, 122.69006942567574, 10.61...
# 5       Mandaue     [123.773858, 124.048004, 10.209113, 10.476077]
# 6      Tacloban  [124.8437, 125.11697419235658, 11.119000306165...
# 7     Zamboanga  [121.85371390413884, 122.48448071157127, 6.812...
# 8  CagayanDeOro  [124.37435854096319, 124.93891405194286, 8.136...
# 9         Davao  [125.05176056799016, 125.81579781461177, 6.868...
#
#                                       focused_bounds
# 0     [120.210342, 120.450668, 15.928978, 16.138177]
# 1     [121.042557, 121.131134, 15.495371, 15.584679]
# 2  [120.8670354518582, 121.20452516891933, 14.293...
# 3      [123.68657, 123.767166, 13.113921, 13.205771]
# 4      [122.477646, 122.602422, 10.676429, 10.80698]
# 5     [123.899689, 123.980026, 10.297017, 10.383142]
# 6       [124.94133, 125.04055, 11.151456, 11.283467]
# 7       [122.013817, 122.199554, 6.852464, 7.015031]
# 8        [124.554405, 124.701691, 8.38679, 8.551884]
# 9       [125.540085, 125.666771, 7.033772, 7.156422]

# %%
CITY_NAMES = bounds_df['city'].unique()
OUTPUT_CITY_NAMES = ['MetroManila' if city_name in ['Muntinlupa', 'Navotas', 'Mandaluyong'] else city_name for city_name in CITY_NAMES]

# %% [markdown]
# ## Read shapefiles

# %%
brgy_gdf = gpd.read_file(RAW_INPUT_PATH / 'domains' / 'target_admin_boundaries.zip')
brgy_gdf.head()
# Out:
#       ADM1_EN   ADM1_PCODE      ADM2_EN   ADM2_PCODE       ADM3_EN  \
# 0    Region I  PH010000000   Pangasinan  PH015500000  Dagupan City
# 1    Region I  PH010000000   Pangasinan  PH015500000  Dagupan City
# 2    Region I  PH010000000   Pangasinan  PH015500000  Dagupan City
# 3    Region I  PH010000000   Pangasinan  PH015500000  Dagupan City
# 4  Region III  PH030000000  Nueva Ecija  PH034900000  Palayan City
#
#     ADM3_PCODE                   ADM4_EN   ADM4_PCODE  \
# 0  PH015518000                    Lomboy  PH015518016
# 1  PH015518000                    Tapuac  PH015518031
# 2  PH015518000                    Pantal  PH015518022
# 3  PH015518000  Barangay I (T. Bugallon)  PH015518024
# 4  PH034919000             Imelda Valley  PH034919017
#
#                                             geometry
# 0  POLYGON ((120.32742 16.05423, 120.32719 16.053...
# 1  POLYGON ((120.33380 16.03974, 120.33389 16.039...
# 2  POLYGON ((120.34737 16.06009, 120.34761 16.060...
# 3  POLYGON ((120.34054 16.04489, 120.34054 16.044...
# 4  POLYGON ((121.12250 15.58028, 121.12687 15.579...

# %%
shp_city_name_lookup = {'Dagupan City':'Dagupan', 'Palayan City':'Palayan', 'Legazpi City':'Legazpi', 'Iloilo City':'Iloilo',
       'Mandaue City':'Mandaue', 'Tacloban City':'Tacloban', 'Zamboanga City':'Zamboanga',
       'Cagayan de Oro City':"CagayanDeOro", 'Davao City':'Davao', 'City of Mandaluyong':'Mandaluyong',
       'City of Navotas':'Navotas', 'City of Muntinlupa':'Muntinlupa'}
city_name_shp_lookup = {y: x for x, y in shp_city_name_lookup.items()}
city_name_shp_lookup.update({'MetroManila': ['City of Navotas','City of Mandaluyong','City of Muntinlupa']})
city_name_shp_lookup
# Out:
# {'Dagupan': 'Dagupan City',
#  'Palayan': 'Palayan City',
#  'Legazpi': 'Legazpi City',
#  'Iloilo': 'Iloilo City',
#  'Mandaue': 'Mandaue City',
#  'Tacloban': 'Tacloban City',
#  'Zamboanga': 'Zamboanga City',
#  'CagayanDeOro': 'Cagayan de Oro City',
#  'Davao': 'Davao City',
#  'Mandaluyong': 'City of Mandaluyong',
#  'Navotas': 'City of Navotas',
#  'Muntinlupa': 'City of Muntinlupa',
#  'MetroManila': ['City of Navotas',
#   'City of Mandaluyong',
#   'City of Muntinlupa']}

# %% [markdown]
# ## Extract per barangay

# %%
city_data_list = []
for city_name in OUTPUT_CITY_NAMES:
    if city_name in EXCLUDED_CITIES:
        continue
    city_shp_lookup = city_name_shp_lookup[city_name] if city_name=='MetroManila' else [city_name_shp_lookup[city_name]]
    excluded_city_shp = [city_name_shp_lookup[city] for city in EXCLUDED_CITIES]
    
    city_brgy_gdf = brgy_gdf[(brgy_gdf['ADM3_EN'].isin(city_shp_lookup))&(~brgy_gdf['ADM3_EN'].isin(excluded_city_shp))].copy()
    if len(city_brgy_gdf)==0:
        continue
    city_brgy_gdf = city_brgy_gdf.to_crs('epsg:4326')
    out_ds = rxr.open_rasterio(RESULTS_PATH / VARIABLE / f"downscaled_{VARIABLE}_{city_name.lower()}_corrected.nc")
    out_ds = out_ds.rio.write_crs('epsg:4326')
    interp_out_ds = out_ds.rio.interpolate_na() # comment out if data is needed in raw form
    brgy_data_list = []
    for i,brgy in city_brgy_gdf.iterrows():
        print(f"Processing {brgy['ADM3_EN']}: BRGY {brgy['ADM4_EN']}...", end='')
        brgy_clipped_ds = interp_out_ds.rio.clip([brgy['geometry']], all_touched=True, drop=True)
        brgy_clipped_mean_ds = brgy_clipped_ds.mean(dim=['x','y']).drop_vars(['spatial_ref'])
        brgy_clipped_mean_df = brgy_clipped_mean_ds.to_dataframe().reset_index()
        brgy_clipped_mean_df['date'] = brgy_clipped_mean_df['time'].apply(lambda x: x.strftime('%Y-%m-%d'))
        brgy_clipped_mean_df[VARIABLE]  = brgy_clipped_mean_df[VARIABLE].round(4)
        brgy_clipped_mean_df['adm4_pcode'] = brgy['ADM4_PCODE']
        brgy_clipped_mean_df['adm3_en'] = brgy['ADM3_EN']
        brgy_clipped_mean_df['adm4_en'] = brgy['ADM4_EN']
        brgy_clipped_mean_df =  brgy_clipped_mean_df[['date','adm4_pcode','adm3_en','adm4_en', VARIABLE]]
        brgy_data_list.append(brgy_clipped_mean_df)
        print('DONE!')

    brgy_data_df = pd.concat(brgy_data_list) 
    city_data_list.append(brgy_data_df)

# %%
# ## Run this for tave
# ## Get mean of tmin and tmax 
# city_data_list = []
# for city_name in OUTPUT_CITY_NAMES:
#     if city_name in EXCLUDED_CITIES:
#         continue
#     city_shp_lookup = city_name_shp_lookup[city_name] if city_name=='MetroManila' else [city_name_shp_lookup[city_name]]
#     excluded_city_shp = [city_name_shp_lookup[city] for city in EXCLUDED_CITIES]
#     city_brgy_gdf = brgy_gdf[(brgy_gdf['ADM3_EN'].isin(city_shp_lookup))&(~brgy_gdf['ADM3_EN'].isin(excluded_city_shp))].copy()
#     if len(city_brgy_gdf)==0:
#         continue
#     city_brgy_gdf = city_brgy_gdf.to_crs('epsg:4326')
#     out1_ds = rxr.open_rasterio(RESULTS_PATH / 'tmin'/ f"downscaled_tmin_{city_name.lower()}_corrected.nc")
#     out1_ds = out1_ds.rio.write_crs('epsg:4326')
#     interp_out1_ds = out1_ds.rio.interpolate_na() # comment out if data is needed in raw form
#     out2_ds = rxr.open_rasterio(RESULTS_PATH / 'tmax'/ f"downscaled_tmax_{city_name.lower()}_corrected.nc")
#     out2_ds = out2_ds.rio.write_crs('epsg:4326')
#     interp_out2_ds = out2_ds.rio.interpolate_na() # comment out if data is needed in raw form
#     interp_out_ds = (interp_out1_ds + interp_out2_ds) / 2
#     interp_out_ds.name = 'tave'

#     brgy_data_list = []
#     for i,brgy in city_brgy_gdf.iterrows():
#         print(f"Processing {brgy['ADM3_EN']}: BRGY {brgy['ADM4_EN']}...", end='')
#         brgy_clipped_ds = interp_out_ds.rio.clip([brgy['geometry']], all_touched=True, drop=True)
#         brgy_clipped_mean_ds = brgy_clipped_ds.mean(dim=['x','y']).drop_vars(['spatial_ref'])
#         brgy_clipped_mean_df = brgy_clipped_mean_ds.to_dataframe().reset_index()
#         brgy_clipped_mean_df['date'] = brgy_clipped_mean_df['time'].apply(lambda x: x.strftime('%Y-%m-%d'))
#         brgy_clipped_mean_df[VARIABLE]  = brgy_clipped_mean_df[VARIABLE].round(4)
#         brgy_clipped_mean_df['adm4_pcode'] = brgy['ADM4_PCODE']
#         brgy_clipped_mean_df['adm3_en'] = brgy['ADM3_EN']
#         brgy_clipped_mean_df['adm4_en'] = brgy['ADM4_EN']
#         brgy_clipped_mean_df =  brgy_clipped_mean_df[['date','adm4_pcode','adm3_en','adm4_en', VARIABLE]]
#         brgy_data_list.append(brgy_clipped_mean_df)
#         print('DONE!')

#     brgy_data_df = pd.concat(brgy_data_list) 
#     city_data_list.append(brgy_data_df)
# Out:
# Processing Dagupan City: BRGY Lomboy...DONE!
# Processing Dagupan City: BRGY Tapuac...DONE!
# Processing Dagupan City: BRGY Pantal...DONE!
# Processing Dagupan City: BRGY Barangay I (T. Bugallon)...DONE!
# Processing Dagupan City: BRGY Pogo Chico...DONE!
# Processing Dagupan City: BRGY Barangay IV (Zamora)...DONE!
# Processing Dagupan City: BRGY Poblacion Oeste...DONE!
# Processing Dagupan City: BRGY Calmay...DONE!
# Processing Dagupan City: BRGY Barangay II (Nueva)...DONE!
# Processing Dagupan City: BRGY Caranglaan...DONE!
# Processing Dagupan City: BRGY Bonuan Gueset...DONE!
# Processing Dagupan City: BRGY Pogo Grande...DONE!
# Processing Dagupan City: BRGY Tebeng...DONE!
# Processing Dagupan City: BRGY Bonuan Binloc...DONE!
# Processing Dagupan City: BRGY Carael...DONE!
# Processing Dagupan City: BRGY Salapingao...DONE!
# Processing Dagupan City: BRGY Bolosan...DONE!
# Processing Dagupan City: BRGY Tambac...DONE!
# Processing Dagupan City: BRGY Mangin...DONE!
# Processing Dagupan City: BRGY Mamalingling...DONE!
# Processing Dagupan City: BRGY Pugaro Suit...DONE!
# Processing Dagupan City: BRGY Bonuan Boquig...DONE!
# Processing Dagupan City: BRGY Salisay...DONE!
# Processing Dagupan City: BRGY Lasip Chico...DONE!
# Processing Dagupan City: BRGY Herrero...DONE!
# Processing Dagupan City: BRGY Lasip Grande...DONE!
# Processing Dagupan City: BRGY Bacayao Sur...DONE!
# Processing Dagupan City: BRGY Mayombo...DONE!
# Processing Dagupan City: BRGY Bacayao Norte...DONE!
# Processing Dagupan City: BRGY Malued...DONE!
# Processing Dagupan City: BRGY Lucao...DONE!
# Processing Palayan City: BRGY Imelda Valley...DONE!
# Processing Palayan City: BRGY Malate (Pob.)...DONE!
# Processing Palayan City: BRGY Doña Josefa...DONE!
# Processing Palayan City: BRGY Popolon Pagas...DONE!
# Processing Palayan City: BRGY Manacnac...DONE!
# Processing Palayan City: BRGY Caballero...DONE!
# Processing Palayan City: BRGY Langka...DONE!
# Processing Palayan City: BRGY Bo. Militar (Fort Magsaysay)...DONE!
# Processing Palayan City: BRGY Ganaderia...DONE!
# Processing Palayan City: BRGY Caimito...DONE!
# Processing Palayan City: BRGY Aulo...DONE!
# Processing Palayan City: BRGY Sapang Buho...DONE!
# Processing Palayan City: BRGY Atate...DONE!
# Processing Palayan City: BRGY Santolan...DONE!
# Processing Palayan City: BRGY Mapait...DONE!
# Processing Palayan City: BRGY Maligaya...DONE!
# Processing Palayan City: BRGY Bagong Buhay...DONE!
# Processing Palayan City: BRGY Singalat...DONE!
# Processing Palayan City: BRGY Marcos Village...DONE!
# Processing Iloilo City: BRGY Our Lady Of Fatima...DONE!
# Processing Iloilo City: BRGY Kauswagan...DONE!
# Processing Iloilo City: BRGY Abeto Mirasol Taft South (Quirino Abeto)...DONE!
# Processing Iloilo City: BRGY Villa Anita...DONE!
# Processing Iloilo City: BRGY Guzman-Jesena...DONE!
# Processing Iloilo City: BRGY Camalig...DONE!
# Processing Iloilo City: BRGY Katilingban...DONE!
# Processing Iloilo City: BRGY Luna (Jaro)...DONE!
# Processing Iloilo City: BRGY San Jose (Jaro)...DONE!
# Processing Iloilo City: BRGY Cubay...DONE!
# Processing Iloilo City: BRGY Timawa Tanza II...DONE!
# Processing Iloilo City: BRGY San Roque...DONE!
# Processing Iloilo City: BRGY Bonifacio (Arevalo)...DONE!
# Processing Iloilo City: BRGY South Fundidor...DONE!
# Processing Iloilo City: BRGY San Pedro (Jaro)...DONE!
# Processing Iloilo City: BRGY Tap-oc...DONE!
# Processing Iloilo City: BRGY Balantang...DONE!
# Processing Iloilo City: BRGY Mabolo-Delgado...DONE!
# Processing Iloilo City: BRGY Tacas...DONE!
# Processing Iloilo City: BRGY Navais...DONE!
# Processing Iloilo City: BRGY Infante...DONE!
# Processing Iloilo City: BRGY Veterans Village...DONE!
# Processing Iloilo City: BRGY Desamparados...DONE!
# Processing Iloilo City: BRGY Santo Niño Sur...DONE!
# Processing Iloilo City: BRGY Hipodromo...DONE!
# Processing Iloilo City: BRGY Santo Rosario-Duran...DONE!
# Processing Iloilo City: BRGY Our Lady Of Lourdes...DONE!
# Processing Iloilo City: BRGY Libertad, Santa Isabel...DONE!
# Processing Iloilo City: BRGY Railway...DONE!
# Processing Iloilo City: BRGY North Fundidor...DONE!
# Processing Iloilo City: BRGY Obrero-Lapuz...DONE!
# Processing Iloilo City: BRGY Gloria...DONE!
# Processing Iloilo City: BRGY Simon Ledesma...DONE!
# Processing Iloilo City: BRGY Lopez Jaena (Jaro)...DONE!
# Processing Iloilo City: BRGY San Nicolas...DONE!
# Processing Iloilo City: BRGY Jalandoni Estate-Lapuz...DONE!
# Processing Iloilo City: BRGY Marcelo H. del Pilar...DONE!
# Processing Iloilo City: BRGY So-oc...DONE!
# Processing Iloilo City: BRGY Loboc-Lapuz...DONE!
# Processing Iloilo City: BRGY Bolilao...DONE!
# Processing Iloilo City: BRGY Alalasan Lapuz...DONE!
# Processing Iloilo City: BRGY San Juan...DONE!
# Processing Iloilo City: BRGY Tabuc Suba (La Paz)...DONE!
# Processing Iloilo City: BRGY Bonifacio Tanza...DONE!
# Processing Iloilo City: BRGY Buhang Taft North...DONE!
# Processing Iloilo City: BRGY Santa Cruz...DONE!
# Processing Iloilo City: BRGY Rizal Palapala II...DONE!
# Processing Iloilo City: BRGY Rizal Estanzuela...DONE!
# Processing Iloilo City: BRGY North Baluarte...DONE!
# Processing Iloilo City: BRGY Bantud...DONE!
# Processing Iloilo City: BRGY Hibao-an Norte...DONE!
# Processing Iloilo City: BRGY Cuartero...DONE!
# Processing Iloilo City: BRGY Monica Blumentritt...DONE!
# Processing Iloilo City: BRGY Mohon...DONE!
# Processing Iloilo City: BRGY Molo Boulevard...DONE!
# Processing Iloilo City: BRGY San Antonio...DONE!
# Processing Iloilo City: BRGY East Baluarte...DONE!
# Processing Iloilo City: BRGY Rizal Ibarra...DONE!
# Processing Iloilo City: BRGY Tabucan...DONE!
# Processing Iloilo City: BRGY Tagbac...DONE!
# Processing Iloilo City: BRGY Edganzon...DONE!
# Processing Iloilo City: BRGY Libertad-Lapuz...DONE!
# Processing Iloilo City: BRGY Progreso-Lapuz...DONE!
# Processing Iloilo City: BRGY Laguda...DONE!
# Processing Iloilo City: BRGY San Rafael...DONE!
# Processing Iloilo City: BRGY Quezon...DONE!
# Processing Iloilo City: BRGY Cochero...DONE!
# Processing Iloilo City: BRGY Caingin...DONE!
# Processing Iloilo City: BRGY Yulo Drive...DONE!
# Processing Iloilo City: BRGY Sambag...DONE!
# Processing Iloilo City: BRGY Lopez Jaena Norte...DONE!
# Processing Iloilo City: BRGY Santa Filomena...DONE!
# Processing Iloilo City: BRGY San Pedro (Molo)...DONE!
# Processing Iloilo City: BRGY Kahirupan...DONE!
# Processing Iloilo City: BRGY Nabitasan...DONE!
# Processing Iloilo City: BRGY Ticud (La Paz)...DONE!
# Processing Iloilo City: BRGY Burgos-Mabini-Plaza...DONE!
# Processing Iloilo City: BRGY Jereos...DONE!
# Processing Iloilo City: BRGY Osmeña...DONE!
# Processing Iloilo City: BRGY San Felix...DONE!
# Processing Iloilo City: BRGY Ortiz...DONE!
# Processing Iloilo City: BRGY Concepcion-Montes...DONE!
# Processing Iloilo City: BRGY Pale Benedicto Rizal (Mandurriao)...DONE!
# Processing Iloilo City: BRGY Santo Niño Norte...DONE!
# Processing Iloilo City: BRGY Taytay Zone II...DONE!
# Processing Iloilo City: BRGY El 98 Castilla (Claudio Lopez)...DONE!
# Processing Iloilo City: BRGY Jalandoni-Wilson...DONE!
# Processing Iloilo City: BRGY Sinikway (Bangkerohan Lapuz)...DONE!
# Processing Iloilo City: BRGY Calahunan...DONE!
# Processing Iloilo City: BRGY Buhang...DONE!
# Processing Iloilo City: BRGY San Isidro (La Paz)...DONE!
# Processing Iloilo City: BRGY Tabuc Suba (Jaro)...DONE!
# Processing Iloilo City: BRGY North San Jose...DONE!
# Processing Iloilo City: BRGY Montinola...DONE!
# Processing Iloilo City: BRGY Dulonan...DONE!
# Processing Iloilo City: BRGY Benedicto (Jaro)...DONE!
# Processing Iloilo City: BRGY Hinactacan...DONE!
# Processing Iloilo City: BRGY Maria Cristina...DONE!
# Processing Iloilo City: BRGY Rizal Palapala I...DONE!
# Processing Iloilo City: BRGY Taal...DONE!
# Processing Iloilo City: BRGY Mansaya-Lapuz...DONE!
# Processing Iloilo City: BRGY M. V. Hechanova...DONE!
# Processing Iloilo City: BRGY East Timawa...DONE!
# Processing Iloilo City: BRGY Balabago...DONE!
# Processing Iloilo City: BRGY Nonoy...DONE!
# Processing Iloilo City: BRGY Kasingkasing...DONE!
# Processing Iloilo City: BRGY Tanza-Esperanza...DONE!
# Processing Iloilo City: BRGY Danao...DONE!
# Processing Iloilo City: BRGY PHHC Block 17...DONE!
# Processing Iloilo City: BRGY Ungka...DONE!
# Processing Iloilo City: BRGY Gustilo...DONE!
# Processing Iloilo City: BRGY San Agustin...DONE!
# Processing Iloilo City: BRGY San Jose (Arevalo)...DONE!
# Processing Iloilo City: BRGY Santa Rosa...DONE!
# Processing Iloilo City: BRGY Calumpang...DONE!
# Processing Iloilo City: BRGY Baldoza...DONE!
# Processing Iloilo City: BRGY President Roxas...DONE!
# Processing Iloilo City: BRGY Magsaysay...DONE!
# Processing Iloilo City: BRGY South Baluarte...DONE!
# Processing Iloilo City: BRGY North Avanceña...DONE!
# Processing Iloilo City: BRGY Calubihan...DONE!
# Processing Iloilo City: BRGY Yulo-Arroyo...DONE!
# Processing Iloilo City: BRGY Arguelles...DONE!
# Processing Iloilo City: BRGY Banuyao...DONE!
# Processing Iloilo City: BRGY Buntatala...DONE!
# Processing Iloilo City: BRGY Seminario (Burgos Jalandoni)...DONE!
# Processing Iloilo City: BRGY Roxas Village...DONE!
# Processing Iloilo City: BRGY Muelle Loney-Montes...DONE!
# Processing Iloilo City: BRGY West Habog-habog...DONE!
# Processing Iloilo City: BRGY Don Esteban-Lapuz...DONE!
# Processing Iloilo City: BRGY Rima-Rizal...DONE!
# Processing Iloilo City: BRGY Lopez Jaena Sur...DONE!
# Processing Iloilo City: BRGY Legaspi dela Rama...DONE!
# Processing Iloilo City: BRGY Macarthur...DONE!
# Processing Iloilo City: BRGY Liberation...DONE!
# Processing Iloilo City: BRGY Aguinaldo...DONE!
# Processing Iloilo City: BRGY Zamora-Melliza...DONE!
# Processing Iloilo City: BRGY Malipayon-Delgado...DONE!
# Processing Iloilo City: BRGY Dungon B...DONE!
# Processing Iloilo City: BRGY Habog-habog Salvacion...DONE!
# Processing Iloilo City: BRGY PHHC Block 22 NHA...DONE!
# Processing Iloilo City: BRGY Javellana...DONE!
# Processing Iloilo City: BRGY Fajardo...DONE!
# Processing Iloilo City: BRGY Bito-on...DONE!
# Processing Iloilo City: BRGY Poblacion Molo...DONE!
# Processing Iloilo City: BRGY South San Jose...DONE!
# Processing Iloilo City: BRGY Lapuz Norte...DONE!
# Processing Iloilo City: BRGY Magdalo...DONE!
# Processing Iloilo City: BRGY Lanit...DONE!
# Processing Iloilo City: BRGY Dungon A...DONE!
# Processing Iloilo City: BRGY San Jose (City Proper)...DONE!
# Processing Iloilo City: BRGY Quintin Salas...DONE!
# Processing Iloilo City: BRGY Baybay Tanza...DONE!
# Processing Iloilo City: BRGY Oñate de Leon...DONE!
# Processing Iloilo City: BRGY Arsenal Aduana...DONE!
# Processing Iloilo City: BRGY West Timawa...DONE!
# Processing Iloilo City: BRGY Dungon...DONE!
# Processing Iloilo City: BRGY Calaparan...DONE!
# Processing Iloilo City: BRGY Maria Clara...DONE!
# Processing Iloilo City: BRGY Democracia...DONE!
# Processing Iloilo City: BRGY Hibao-an Sur...DONE!
# Processing Iloilo City: BRGY Ingore...DONE!
# Processing Iloilo City: BRGY Inday...DONE!
# Processing Iloilo City: BRGY Luna (La Paz)...DONE!
# Processing Iloilo City: BRGY Punong-Lapuz...DONE!
# Processing Iloilo City: BRGY Magsaysay Village...DONE!
# Processing Iloilo City: BRGY Airport (Tabucan Airport)...DONE!
# Processing Iloilo City: BRGY Compania...DONE!
# Processing Iloilo City: BRGY San Vicente...DONE!
# Processing Iloilo City: BRGY Bakhaw...DONE!
# Processing Iloilo City: BRGY Santo Domingo...DONE!
# Processing Iloilo City: BRGY San Isidro (Jaro)...DONE!
# Processing Iloilo City: BRGY Divinagracia...DONE!
# Processing Iloilo City: BRGY General Hughes-Montes...DONE!
# Processing Iloilo City: BRGY Sampaguita...DONE!
# Processing Iloilo City: BRGY Timawa Tanza I...DONE!
# Processing Iloilo City: BRGY Rizal (La Paz)...DONE!
# Processing Iloilo City: BRGY Lapuz Sur...DONE!
# Processing Iloilo City: BRGY Flores...DONE!
# Processing Iloilo City: BRGY Delgado-Jalandoni-Bagumbayan...DONE!
# Processing Tacloban City: BRGY Barangay 103-A (San Paglaum)...DONE!
# Processing Tacloban City: BRGY Barangay 39...DONE!
# Processing Tacloban City: BRGY Barangay 90 (San Jose)...DONE!
# Processing Tacloban City: BRGY Barangay 95 (Caibaan)...DONE!
# Processing Tacloban City: BRGY Barangay 44-A...DONE!
# Processing Tacloban City: BRGY Barangay 13...DONE!
# Processing Tacloban City: BRGY Barangay 94 (Tigbao)...DONE!
# Processing Tacloban City: BRGY Barangay 26...DONE!
# Processing Tacloban City: BRGY Barangay 22...DONE!
# Processing Tacloban City: BRGY Barangay 99 (Diit)...DONE!
# Processing Tacloban City: BRGY Barangay 43...DONE!
# Processing Tacloban City: BRGY Barangay 49...DONE!
# Processing Tacloban City: BRGY Barangay 80 (Marasbaras)...DONE!
# Processing Tacloban City: BRGY Barangay 36...DONE!
# Processing Tacloban City: BRGY Barangay 50...DONE!
# Processing Tacloban City: BRGY Barangay 58...DONE!
# Processing Tacloban City: BRGY Barangay 91 (Abucay)...DONE!
# Processing Tacloban City: BRGY Barangay 6...DONE!
# Processing Tacloban City: BRGY Barangay 87...DONE!
# Processing Tacloban City: BRGY Barangay 81 (Marasbaras)...DONE!
# Processing Tacloban City: BRGY Barangay 83-C (San Jose)...DONE!
# Processing Tacloban City: BRGY Barangay 38...DONE!
# Processing Tacloban City: BRGY Barangay 32...DONE!
# Processing Tacloban City: BRGY Barangay 78 (Marasbaras)...DONE!
# Processing Tacloban City: BRGY Barangay 41...DONE!
# Processing Tacloban City: BRGY Barangay 5-A...DONE!
# Processing Tacloban City: BRGY Barangay 82 (Marasbaras)...DONE!
# Processing Tacloban City: BRGY Barangay 62-B...DONE!
# Processing Tacloban City: BRGY Barangay 98 (Camansinay)...DONE!
# Processing Tacloban City: BRGY Barangay 66...DONE!
# Processing Tacloban City: BRGY Barangay 68...DONE!
# Processing Tacloban City: BRGY Barangay 48-A...DONE!
# Processing Tacloban City: BRGY Barangay 28...DONE!
# Processing Tacloban City: BRGY Barangay 35...DONE!
# Processing Tacloban City: BRGY Barangay 85 (San Jose)...DONE!
# Processing Tacloban City: BRGY Barangay 103 (Palanog)...DONE!
# Processing Tacloban City: BRGY Barangay 84 (San Jose)...DONE!
# Processing Tacloban City: BRGY Barangay 5...DONE!
# Processing Tacloban City: BRGY Barangay 79 (Marasbaras)...DONE!
# Processing Tacloban City: BRGY Barangay 12 (Palanog Resettlement)...DONE!
# Processing Tacloban City: BRGY Barangay 18...DONE!
# Processing Tacloban City: BRGY Barangay 48...DONE!
# Processing Tacloban City: BRGY Barangay 52...DONE!
# Processing Tacloban City: BRGY Barangay 36-A...DONE!
# Processing Tacloban City: BRGY Barangay 23...DONE!
# Processing Tacloban City: BRGY Barangay 89...DONE!
# Processing Tacloban City: BRGY Barangay 66-A...DONE!
# Processing Tacloban City: BRGY Barangay 43-A...DONE!
# Processing Tacloban City: BRGY Barangay 110 (Utap)...DONE!
# Processing Tacloban City: BRGY Barangay 97 (Cabalawan)...DONE!
# Processing Tacloban City: BRGY Barangay 47...DONE!
# Processing Tacloban City: BRGY Barangay 104 (Salvacion)...DONE!
# Processing Tacloban City: BRGY Barangay 76...DONE!
# Processing Tacloban City: BRGY Barangay 105 (Suhi)...DONE!
# Processing Tacloban City: BRGY Barangay 65...DONE!
# Processing Tacloban City: BRGY Barangay 108 (Tagapuro)...DONE!
# Processing Tacloban City: BRGY Barangay 45...DONE!
# Processing Tacloban City: BRGY Barangay 64...DONE!
# Processing Tacloban City: BRGY Barangay 83 (San Jose)...DONE!
# Processing Tacloban City: BRGY Barangay 20...DONE!
# Processing Tacloban City: BRGY Barangay 56...DONE!
# Processing Tacloban City: BRGY Barangay 40...DONE!
# Processing Tacloban City: BRGY Barangay 19...DONE!
# Processing Tacloban City: BRGY Barangay 42...DONE!
# Processing Tacloban City: BRGY Barangay 46...DONE!
# Processing Tacloban City: BRGY Barangay 60-A...DONE!
# Processing Tacloban City: BRGY Barangay 16...DONE!
# Processing Tacloban City: BRGY Barangay 95-A (Caibaan)...DONE!
# Processing Tacloban City: BRGY Barangay 8...DONE!
# Processing Tacloban City: BRGY Barangay 53...DONE!
# Processing Tacloban City: BRGY Barangay 17...DONE!
# Processing Tacloban City: BRGY Barangay 21...DONE!
# Processing Tacloban City: BRGY Barangay 67...DONE!
# Processing Tacloban City: BRGY Barangay 83-B...DONE!
# Processing Tacloban City: BRGY Barangay 100 (San Roque)...DONE!
# Processing Tacloban City: BRGY Barangay 86...DONE!
# Processing Tacloban City: BRGY Barangay 34...DONE!
# Processing Tacloban City: BRGY Barangay 29...DONE!
# Processing Tacloban City: BRGY Barangay 33...DONE!
# Processing Tacloban City: BRGY Barangay 73...DONE!
# Processing Tacloban City: BRGY Barangay 101 (New Kawayan)...DONE!
# Processing Tacloban City: BRGY Barangay 69...DONE!
# Processing Tacloban City: BRGY Barangay 42-A...DONE!
# Processing Tacloban City: BRGY Barangay 92 (Apitong)...DONE!
# Processing Tacloban City: BRGY Barangay 50-B...DONE!
# Processing Tacloban City: BRGY Libertad (Barangays 1 & 4)...DONE!
# Processing Tacloban City: BRGY Barangay 93 (Bagacay)...DONE!
# Processing Tacloban City: BRGY El Reposo (Barangays 55 & 55A)...DONE!
# Processing Tacloban City: BRGY Barangay 31...DONE!
# Processing Tacloban City: BRGY Barangay 14...DONE!
# Processing Tacloban City: BRGY Barangay 6-A...DONE!
# Processing Tacloban City: BRGY Barangay 21-A...DONE!
# Processing Tacloban City: BRGY Barangay 24...DONE!
# Processing Tacloban City: BRGY Barangay 74...DONE!
# Processing Tacloban City: BRGY Nula-tula (Bgys. 3 & 3A)...DONE!
# Processing Tacloban City: BRGY Barangay 50-A...DONE!
# Processing Tacloban City: BRGY Barangay 109-A...DONE!
# Processing Tacloban City: BRGY Barangay 59-B...DONE!
# Processing Tacloban City: BRGY Barangay 37-A...DONE!
# Processing Tacloban City: BRGY Barangay 107 (Santa Elena)...DONE!
# Processing Tacloban City: BRGY Barangay 88...DONE!
# Processing Tacloban City: BRGY Barangay 57...DONE!
# Processing Tacloban City: BRGY Barangay 75...DONE!
# Processing Tacloban City: BRGY Barangay 30...DONE!
# Processing Tacloban City: BRGY Barangay 59-A...DONE!
# Processing Tacloban City: BRGY Barangay 62...DONE!
# Processing Tacloban City: BRGY Barangay 71...DONE!
# Processing Tacloban City: BRGY Barangay 77...DONE!
# Processing Tacloban City: BRGY Barangay 94-A...DONE!
# Processing Tacloban City: BRGY Barangay 63...DONE!
# Processing Tacloban City: BRGY Barangay 70...DONE!
# Processing Tacloban City: BRGY Barangay 72...DONE!
# Processing Tacloban City: BRGY Barangay 35-A...DONE!
# Processing Tacloban City: BRGY Barangay 60...DONE!
# Processing Tacloban City: BRGY Barangay 2...DONE!
# Processing Tacloban City: BRGY Barangay 23-A...DONE!
# Processing Tacloban City: BRGY Barangay 51...DONE!
# Processing Tacloban City: BRGY Barangay 25...DONE!
# Processing Tacloban City: BRGY Barangay 56-A...DONE!
# Processing Tacloban City: BRGY Barangay 51-A...DONE!
# Processing Tacloban City: BRGY Barangay 44...DONE!
# Processing Tacloban City: BRGY Barangay 102 (Old Kawayan)...DONE!
# Processing Tacloban City: BRGY Barangay 8-A...DONE!
# Processing Tacloban City: BRGY Barangay 106 (Santo Niño)...DONE!
# Processing Tacloban City: BRGY Barangay 109 (V & G Subd.)...DONE!
# Processing Tacloban City: BRGY Barangay 61...DONE!
# Processing Tacloban City: BRGY Barangay 15...DONE!
# Processing Tacloban City: BRGY Barangay 59...DONE!
# Processing Tacloban City: BRGY Barangay 54...DONE!
# Processing Tacloban City: BRGY Barangay 43-B...DONE!
# Processing Tacloban City: BRGY Barangay 48-B...DONE!
# Processing Tacloban City: BRGY Barangay 62-A...DONE!
# Processing Tacloban City: BRGY Barangay 83-A (San Jose)...DONE!
# Processing Tacloban City: BRGY Barangay 37...DONE!
# Processing Tacloban City: BRGY Barangay 27...DONE!
# Processing Tacloban City: BRGY Barangay 96 (Calanipawan)...DONE!
# Processing Tacloban City: BRGY Barangay 54-A...DONE!
# Processing Tacloban City: BRGY Barangay 7...DONE!
# Processing Zamboanga City: BRGY Barangay Zone II (Pob.)...DONE!
# Processing Zamboanga City: BRGY Dulian (Upper Pasonanca)...DONE!
# Processing Zamboanga City: BRGY Recodo...DONE!
# Processing Zamboanga City: BRGY Tumalutab...DONE!
# Processing Zamboanga City: BRGY Patalon...DONE!
# Processing Zamboanga City: BRGY Lamisahan...DONE!
# Processing Zamboanga City: BRGY Unclaimed Area under Jurisdiction of Zamboanga City...DONE!
# Processing Zamboanga City: BRGY Dulian (Upper Bunguiao)...DONE!
# Processing Zamboanga City: BRGY Pangapuyan...DONE!
# Processing Zamboanga City: BRGY Lumbangan...DONE!
# Processing Zamboanga City: BRGY Campo Islam...DONE!
# Processing Zamboanga City: BRGY Tulungatung...DONE!
# Processing Zamboanga City: BRGY Malagutay...DONE!
# Processing Zamboanga City: BRGY Manicahan...DONE!
# Processing Zamboanga City: BRGY Barangay Zone I (Pob.)...DONE!
# Processing Zamboanga City: BRGY Tigtabon...DONE!
# Processing Zamboanga City: BRGY Pasonanca Natural Park under Jurisdiction of Zamboanga City...DONE!
# Processing Zamboanga City: BRGY Sinunoc...DONE!
# Processing Zamboanga City: BRGY Lapakan...DONE!
# Processing Zamboanga City: BRGY Licomo...DONE!
# Processing Zamboanga City: BRGY Tugbungan...DONE!
# Processing Zamboanga City: BRGY Vitali...DONE!
# Processing Zamboanga City: BRGY Tumitus...DONE!
# Processing Zamboanga City: BRGY Culianan...DONE!
# Processing Zamboanga City: BRGY Boalan...DONE!
# Processing Zamboanga City: BRGY San Jose Cawa-cawa...DONE!
# Processing Zamboanga City: BRGY Capisan...DONE!
# Processing Zamboanga City: BRGY Mangusu...DONE!
# Processing Zamboanga City: BRGY Latuan (Curuan)...DONE!
# Processing Zamboanga City: BRGY Barangay Zone IV (Pob.)...DONE!
# Processing Zamboanga City: BRGY Sangali...DONE!
# Processing Zamboanga City: BRGY Santa Maria...DONE!
# Processing Zamboanga City: BRGY La Paz...DONE!
# Processing Zamboanga City: BRGY Ayala...DONE!
# Processing Zamboanga City: BRGY Camino Nuevo...DONE!
# Processing Zamboanga City: BRGY Tigbalabag...DONE!
# Processing Zamboanga City: BRGY Kasanyangan...DONE!
# Processing Zamboanga City: BRGY Mercedes...DONE!
# Processing Zamboanga City: BRGY San Jose Gusu...DONE!
# Processing Zamboanga City: BRGY Lanzones...DONE!
# Processing Zamboanga City: BRGY Talon-talon...DONE!
# Processing Zamboanga City: BRGY Watershed Area under Jurisdiction of Zamboanga City...DONE!
# Processing Zamboanga City: BRGY Arena Blanco...DONE!
# Processing Zamboanga City: BRGY Talabaan...DONE!
# Processing Zamboanga City: BRGY Tetuan...DONE!
# Processing Zamboanga City: BRGY Lumayang...DONE!
# Processing Zamboanga City: BRGY Canelar...DONE!
# Processing Zamboanga City: BRGY Talisayan...DONE!
# Processing Zamboanga City: BRGY Landang Gua...DONE!
# Processing Zamboanga City: BRGY Guiwan...DONE!
# Processing Zamboanga City: BRGY Cacao...DONE!
# Processing Zamboanga City: BRGY Maasin...DONE!
# Processing Zamboanga City: BRGY Calarian...DONE!
# Processing Zamboanga City: BRGY Baliwasan...DONE!
# Processing Zamboanga City: BRGY Mariki...DONE!
# Processing Zamboanga City: BRGY Pasilmanta (Sacol Island)...DONE!
# Processing Zamboanga City: BRGY Lunzuran...DONE!
# Processing Zamboanga City: BRGY Mampang...DONE!
# Processing Zamboanga City: BRGY Labuan...DONE!
# Processing Zamboanga City: BRGY Cabatangan...DONE!
# Processing Zamboanga City: BRGY Barangay Zone III (Pob.)...DONE!
# Processing Zamboanga City: BRGY Divisoria...DONE!
# Processing Zamboanga City: BRGY Salaan...DONE!
# Processing Zamboanga City: BRGY Pasonanca...DONE!
# Processing Zamboanga City: BRGY Tolosa...DONE!
# Processing Zamboanga City: BRGY San Roque...DONE!
# Processing Zamboanga City: BRGY Santa Barbara...DONE!
# Processing Zamboanga City: BRGY Limpapa...DONE!
# Processing Zamboanga City: BRGY Zambowood...DONE!
# Processing Zamboanga City: BRGY Rio Hondo...DONE!
# Processing Zamboanga City: BRGY Baluno...DONE!
# Processing Zamboanga City: BRGY Sinubung...DONE!
# Processing Zamboanga City: BRGY Curuan...DONE!
# Processing Zamboanga City: BRGY Dita...DONE!
# Processing Zamboanga City: BRGY Santa Catalina...DONE!
# Processing Zamboanga City: BRGY Pasobolong...DONE!
# Processing Zamboanga City: BRGY Limaong...DONE!
# Processing Zamboanga City: BRGY Muti...DONE!
# Processing Zamboanga City: BRGY Santo Niño...DONE!
# Processing Zamboanga City: BRGY Lubigan...DONE!
# Processing Zamboanga City: BRGY Tumaga...DONE!
# Processing Zamboanga City: BRGY Landang Laum...DONE!
# Processing Zamboanga City: BRGY Quiniput...DONE!
# Processing Zamboanga City: BRGY Buenavista...DONE!
# Processing Zamboanga City: BRGY Putik...DONE!
# Processing Zamboanga City: BRGY Tictapul...DONE!
# Processing Zamboanga City: BRGY Cabaluay...DONE!
# Processing Zamboanga City: BRGY Bunguiao...DONE!
# Processing Zamboanga City: BRGY Pamucutan...DONE!
# Processing Zamboanga City: BRGY Calabasa...DONE!
# Processing Zamboanga City: BRGY Bolong...DONE!
# Processing Zamboanga City: BRGY Taguiti...DONE!
# Processing Zamboanga City: BRGY Taluksangay...DONE!
# Processing Zamboanga City: BRGY Busay (Sacol Island)...DONE!
# Processing Zamboanga City: BRGY Sibulao (Caruan)...DONE!
# Processing Zamboanga City: BRGY Manalipa...DONE!
# Processing Zamboanga City: BRGY Guisao...DONE!
# Processing Zamboanga City: BRGY Panubigan...DONE!
# Processing Zamboanga City: BRGY Cawit...DONE!
# Processing Zamboanga City: BRGY Tagasilay...DONE!
# Processing Zamboanga City: BRGY Victoria...DONE!

# %%
all_data_df = pd.concat(city_data_list) 
all_data_df
# Out:
#             date   adm4_pcode         adm3_en   adm4_en     tave
# 0     2003-01-01  PH015518016    Dagupan City    Lomboy  27.2730
# 1     2003-01-02  PH015518016    Dagupan City    Lomboy  25.7941
# 2     2003-01-03  PH015518016    Dagupan City    Lomboy  24.6129
# 3     2003-01-04  PH015518016    Dagupan City    Lomboy  24.7932
# 4     2003-01-05  PH015518016    Dagupan City    Lomboy  25.0476
# ...          ...          ...             ...       ...      ...
# 7300  2022-12-27  PH097332103  Zamboanga City  Victoria  28.4305
# 7301  2022-12-28  PH097332103  Zamboanga City  Victoria  27.8313
# 7302  2022-12-29  PH097332103  Zamboanga City  Victoria  28.2872
# 7303  2022-12-30  PH097332103  Zamboanga City  Victoria  27.2073
# 7304  2022-12-31  PH097332103  Zamboanga City  Victoria  27.8304
#
# [3426045 rows x 5 columns]

# %%
all_data_df['adm3_en'].unique()
# Out:
# array(['Dagupan City', 'Palayan City', 'Iloilo City', 'Tacloban City',
#        'Zamboanga City'], dtype=object)

# %%
all_data_df = all_data_df[~all_data_df['adm3_en'].isin(excluded_city_shp)]

# %%
all_data_df[['date','adm4_pcode',VARIABLE]].to_csv(RESULTS_PATH /'table_extracts'/ f"climate_atmosphere_downscaled_{VARIABLE}.csv", index=False)

# %%
# # check plot time series
# data_df = data_pr_df[data_pr_df['adm4_pcode']=='PH015518016'].copy()
# data_df = data_df.set_index(pd.to_datetime(data_df['date']))
# data_df['pr'].iloc[:720].plot()

# %%
# # check if brgy is within data
# fig,ax = plt.subplots()
# out_ds.isel(time=0).plot(ax=ax)
# city_brgy_gdf.iloc[[0]].boundary.plot(color='black', ax=ax)
